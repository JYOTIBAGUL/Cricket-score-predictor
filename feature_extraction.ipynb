# %%
import pandas as pd
import pickle
import numpy as np

# %%
import os

cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory
print("Files in %r: %s" % (cwd, files))
# Out:
# Files in '/content': ['.config', 'dataset_level1.pkl', '.ipynb_checkpoints', 'dataset_level2.pkl', 'data', 'sample_data']

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))

# %%
df

# batting_team
# bowling team
# city
# current score
# ball left
# wickets left
# current rr
# last five
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city  \
# 0           2    Australia    Sri Lanka   0.1     0                0      NaN
# 1           2    Australia    Sri Lanka   0.2     0                0      NaN
# 2           2    Australia    Sri Lanka   0.3     1                0      NaN
# 3           2    Australia    Sri Lanka   0.4     2                0      NaN
# 4           2    Australia    Sri Lanka   0.5     0                0      NaN
# ..        ...          ...          ...   ...   ...              ...      ...
# 121       964    Sri Lanka    Australia  19.3     1                0  Colombo
# 122       964    Sri Lanka    Australia  19.4     0                0  Colombo
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva  Colombo
# 124       964    Sri Lanka    Australia  19.6     2                0  Colombo
# 125       964    Sri Lanka    Australia  19.7     1                0  Colombo
#
#                         venue
# 0    Melbourne Cricket Ground
# 1    Melbourne Cricket Ground
# 2    Melbourne Cricket Ground
# 3    Melbourne Cricket Ground
# 4    Melbourne Cricket Ground
# ..                        ...
# 121       R Premadasa Stadium
# 122       R Premadasa Stadium
# 123       R Premadasa Stadium
# 124       R Premadasa Stadium
# 125       R Premadasa Stadium
#
# [63888 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8419
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium        3092
# Pallekele International Cricket Stadium    1941
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Harare Sports Club                          372
# Adelaide Oval                               371
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           8    Australia    Sri Lanka   0.1     0                0
# 1           8    Australia    Sri Lanka   0.2     1                0
# 2           8    Australia    Sri Lanka   0.3     1                0
# 3           8    Australia    Sri Lanka   0.4     0                0
# 4           8    Australia    Sri Lanka   0.5     0        SR Watson
# ..        ...          ...          ...   ...   ...              ...
# 122       905        India  West Indies  19.2     6                0
# 123       905        India  West Indies  19.3     0                0
# 124       905        India  West Indies  19.4     1                0
# 125       905        India  West Indies  19.5     6                0
# 126       905        India  West Indies  19.6     1                0
#
#            city
# 0      Barbados
# 1      Barbados
# 2      Barbados
# 3      Barbados
# 4      Barbados
# ..          ...
# 122  Lauderhill
# 123  Lauderhill
# 124  Lauderhill
# 125  Lauderhill
# 126  Lauderhill
#
# [62247 rows x 7 columns]

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           8    Australia    Sri Lanka   0.1     0                0
# 1           8    Australia    Sri Lanka   0.2     1                0
# 2           8    Australia    Sri Lanka   0.3     1                0
# 3           8    Australia    Sri Lanka   0.4     0                0
# 4           8    Australia    Sri Lanka   0.5     0        SR Watson
# ..        ...          ...          ...   ...   ...              ...
# 122       905        India  West Indies  19.2     6                0
# 123       905        India  West Indies  19.3     0                0
# 124       905        India  West Indies  19.4     1                0
# 125       905        India  West Indies  19.5     6                0
# 126       905        India  West Indies  19.6     1                0
#
#            city
# 0      Barbados
# 1      Barbados
# 2      Barbados
# 3      Barbados
# 4      Barbados
# ..          ...
# 122  Lauderhill
# 123  Lauderhill
# 124  Lauderhill
# 125  Lauderhill
# 126  Lauderhill
#
# [48116 rows x 7 columns]

# %%
df['current_score'] = df.groupby('match_id').cumsum()['runs']
# Out:
# <ipython-input-18-ac174c139314>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df['current_score'] = df.groupby('match_id').cumsum()['runs']
# <ipython-input-18-ac174c139314>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score'] = df.groupby('match_id').cumsum()['runs']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           8    Australia    Sri Lanka   0.1     0                0
# 1           8    Australia    Sri Lanka   0.2     1                0
# 2           8    Australia    Sri Lanka   0.3     1                0
# 3           8    Australia    Sri Lanka   0.4     0                0
# 4           8    Australia    Sri Lanka   0.5     0        SR Watson
# ..        ...          ...          ...   ...   ...              ...
# 122       905        India  West Indies  19.2     6                0
# 123       905        India  West Indies  19.3     0                0
# 124       905        India  West Indies  19.4     1                0
# 125       905        India  West Indies  19.5     6                0
# 126       905        India  West Indies  19.6     1                0
#
#            city  current_score
# 0      Barbados              0
# 1      Barbados              1
# 2      Barbados              2
# 3      Barbados              2
# 4      Barbados              2
# ..          ...            ...
# 122  Lauderhill            159
# 123  Lauderhill            159
# 124  Lauderhill            160
# 125  Lauderhill            166
# 126  Lauderhill            167
#
# [48116 rows x 8 columns]

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
# <ipython-input-20-4fd5a57c1fcd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
# <ipython-input-20-4fd5a57c1fcd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           8    Australia    Sri Lanka   0.1     0                0
# 1           8    Australia    Sri Lanka   0.2     1                0
# 2           8    Australia    Sri Lanka   0.3     1                0
# 3           8    Australia    Sri Lanka   0.4     0                0
# 4           8    Australia    Sri Lanka   0.5     0        SR Watson
# ..        ...          ...          ...   ...   ...              ...
# 122       905        India  West Indies  19.2     6                0
# 123       905        India  West Indies  19.3     0                0
# 124       905        India  West Indies  19.4     1                0
# 125       905        India  West Indies  19.5     6                0
# 126       905        India  West Indies  19.6     1                0
#
#            city  current_score over ball_no
# 0      Barbados              0    0       1
# 1      Barbados              1    0       2
# 2      Barbados              2    0       3
# 3      Barbados              2    0       4
# 4      Barbados              2    0       5
# ..          ...            ...  ...     ...
# 122  Lauderhill            159   19       2
# 123  Lauderhill            159   19       3
# 124  Lauderhill            160   19       4
# 125  Lauderhill            166   19       5
# 126  Lauderhill            167   19       6
#
# [48116 rows x 10 columns]

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
# <ipython-input-21-e7d17f656852>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           8    Australia    Sri Lanka   0.1     0                0
# 1           8    Australia    Sri Lanka   0.2     1                0
# 2           8    Australia    Sri Lanka   0.3     1                0
# 3           8    Australia    Sri Lanka   0.4     0                0
# 4           8    Australia    Sri Lanka   0.5     0        SR Watson
# ..        ...          ...          ...   ...   ...              ...
# 122       905        India  West Indies  19.2     6                0
# 123       905        India  West Indies  19.3     0                0
# 124       905        India  West Indies  19.4     1                0
# 125       905        India  West Indies  19.5     6                0
# 126       905        India  West Indies  19.6     1                0
#
#            city  current_score over ball_no  balls_bowled
# 0      Barbados              0    0       1             1
# 1      Barbados              1    0       2             2
# 2      Barbados              2    0       3             3
# 3      Barbados              2    0       4             4
# 4      Barbados              2    0       5             5
# ..          ...            ...  ...     ...           ...
# 122  Lauderhill            159   19       2           116
# 123  Lauderhill            159   19       3           117
# 124  Lauderhill            160   19       4           118
# 125  Lauderhill            166   19       5           119
# 126  Lauderhill            167   19       6           120
#
# [48116 rows x 11 columns]

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
# <ipython-input-22-7ed065e8960c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 120 - df['balls_bowled']
# <ipython-input-22-7ed065e8960c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           8    Australia    Sri Lanka   0.1     0                0
# 1           8    Australia    Sri Lanka   0.2     1                0
# 2           8    Australia    Sri Lanka   0.3     1                0
# 3           8    Australia    Sri Lanka   0.4     0                0
# 4           8    Australia    Sri Lanka   0.5     0        SR Watson
# ..        ...          ...          ...   ...   ...              ...
# 122       905        India  West Indies  19.2     6                0
# 123       905        India  West Indies  19.3     0                0
# 124       905        India  West Indies  19.4     1                0
# 125       905        India  West Indies  19.5     6                0
# 126       905        India  West Indies  19.6     1                0
#
#            city  current_score over ball_no  balls_bowled  balls_left
# 0      Barbados              0    0       1             1         119
# 1      Barbados              1    0       2             2         118
# 2      Barbados              2    0       3             3         117
# 3      Barbados              2    0       4             4         116
# 4      Barbados              2    0       5             5         115
# ..          ...            ...  ...     ...           ...         ...
# 122  Lauderhill            159   19       2           116           4
# 123  Lauderhill            159   19       3           117           3
# 124  Lauderhill            160   19       4           118           2
# 125  Lauderhill            166   19       5           119           1
# 126  Lauderhill            167   19       6           120           0
#
# [48116 rows x 12 columns]

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# <ipython-input-23-e0234112d42f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
# <ipython-input-23-e0234112d42f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype('int')
# <ipython-input-23-e0234112d42f>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
# <ipython-input-23-e0234112d42f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
# <ipython-input-23-e0234112d42f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['wickets_left'] = 10 - df['player_dismissed']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           8    Australia    Sri Lanka   0.1     0                 0
# 1           8    Australia    Sri Lanka   0.2     1                 0
# 2           8    Australia    Sri Lanka   0.3     1                 0
# 3           8    Australia    Sri Lanka   0.4     0                 0
# 4           8    Australia    Sri Lanka   0.5     0                 1
# ..        ...          ...          ...   ...   ...               ...
# 122       905        India  West Indies  19.2     6                 5
# 123       905        India  West Indies  19.3     0                 5
# 124       905        India  West Indies  19.4     1                 5
# 125       905        India  West Indies  19.5     6                 5
# 126       905        India  West Indies  19.6     1                 5
#
#            city  current_score over ball_no  balls_bowled  balls_left  \
# 0      Barbados              0    0       1             1         119
# 1      Barbados              1    0       2             2         118
# 2      Barbados              2    0       3             3         117
# 3      Barbados              2    0       4             4         116
# 4      Barbados              2    0       5             5         115
# ..          ...            ...  ...     ...           ...         ...
# 122  Lauderhill            159   19       2           116           4
# 123  Lauderhill            159   19       3           117           3
# 124  Lauderhill            160   19       4           118           2
# 125  Lauderhill            166   19       5           119           1
# 126  Lauderhill            167   19       6           120           0
#
#      wickets_left
# 0              10
# 1              10
# 2              10
# 3              10
# 4               9
# ..            ...
# 122             5
# 123             5
# 124             5
# 125             5
# 126             5
#
# [48116 rows x 13 columns]

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
# Out:
# <ipython-input-25-fad47fc85776>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           8    Australia    Sri Lanka   0.1     0                 0
# 1           8    Australia    Sri Lanka   0.2     1                 0
# 2           8    Australia    Sri Lanka   0.3     1                 0
# 3           8    Australia    Sri Lanka   0.4     0                 0
# 4           8    Australia    Sri Lanka   0.5     0                 1
# ..        ...          ...          ...   ...   ...               ...
# 122       905        India  West Indies  19.2     6                 5
# 123       905        India  West Indies  19.3     0                 5
# 124       905        India  West Indies  19.4     1                 5
# 125       905        India  West Indies  19.5     6                 5
# 126       905        India  West Indies  19.6     1                 5
#
#            city  current_score over ball_no  balls_bowled  balls_left  \
# 0      Barbados              0    0       1             1         119
# 1      Barbados              1    0       2             2         118
# 2      Barbados              2    0       3             3         117
# 3      Barbados              2    0       4             4         116
# 4      Barbados              2    0       5             5         115
# ..          ...            ...  ...     ...           ...         ...
# 122  Lauderhill            159   19       2           116           4
# 123  Lauderhill            159   19       3           117           3
# 124  Lauderhill            160   19       4           118           2
# 125  Lauderhill            166   19       5           119           1
# 126  Lauderhill            167   19       6           120           0
#
#      wickets_left       crr
# 0              10  0.000000
# 1              10  3.000000
# 2              10  4.000000
# 3              10  3.000000
# 4               9  2.400000
# ..            ...       ...
# 122             5  8.224138
# 123             5  8.153846
# 124             5  8.135593
# 125             5  8.369748
# 126             5  8.350000
#
# [48116 rows x 14 columns]

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())
# Out:
# <ipython-input-27-3b88d12c2886>:6: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['batting_team', 'bowling_team', 'city'], dtype='object')
#   last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
df['last_five'] = last_five
# Out:
# <ipython-input-28-83d24d575aa4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
#df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','']]

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')
# Out:
# <ipython-input-31-72dae5031817>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample(2)
# Out:
#       batting_team  bowling_team       city  current_score  balls_left  \
# 8139    Bangladesh  South Africa  Cape Town            104          45
# 33108  New Zealand      Pakistan   Hamilton            123          29
#
#        wickets_left      crr  last_five  runs_x
# 8139              4  8.32000       26.0     144
# 33108             7  8.10989       40.0     185

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#        batting_team  bowling_team        city  current_score  balls_left  \
# 21785  South Africa     Australia   Cape Town            124          29
# 15903  South Africa       England      Mumbai            205          10
# 25967  South Africa     Sri Lanka     Colombo             65          36
# 43756  South Africa   New Zealand    Auckland             79          69
# 39931   West Indies   New Zealand    Auckland             43          67
# ...             ...           ...         ...            ...         ...
# 4571    West Indies   Afghanistan    St Kitts             77          61
# 36679         India   New Zealand    Hamilton            161           6
# 30908     Australia    Bangladesh    Barbados            136           2
# 13534      Pakistan  South Africa  Nottingham             96          46
# 20696   West Indies      Pakistan    Barbados             95          11
#
#        wickets_left        crr  last_five
# 21785             7   8.175824       36.0
# 15903             6  11.181818       58.0
# 25967             6   4.642857       21.0
# 43756             9   9.294118       60.0
# 39931             7   4.867925       29.0
# ...             ...        ...        ...
# 4571              8   7.830508       26.0
# 36679             5   8.473684       46.0
# 30908             4   6.915254       54.0
# 13534             7   7.783784       44.0
# 20696             3   5.229358       36.0
#
# [29327 rows x 8 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 0.9877644107798585
# 1.577299065493653

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
import xgboost
xgboost.__version__
# Out:
# '2.0.2'

# %%
eligible_cities
# Out:
# ['Colombo',
#  'Mirpur',
#  'Dubai',
#  'Johannesburg',
#  'Auckland',
#  'Cape Town',
#  'London',
#  'Pallekele',
#  'Barbados',
#  'Melbourne',
#  'Durban',
#  'St Lucia',
#  'Wellington',
#  'Sydney',
#  'Lauderhill',
#  'Centurion',
#  'Manchester',
#  'Hamilton',
#  'Abu Dhabi',
#  'Mumbai',
#  'Nottingham',
#  'Southampton',
#  'Chittagong',
#  'Kolkata',
#  'Mount Maunganui',
#  'Delhi',
#  'Cardiff',
#  'Chandigarh',
#  'Bangalore',
#  'St Kitts',
#  'Christchurch',
#  'Nagpur',
#  'Trinidad']
